# %%
import argparse
import torch
import torch.nn as nn
import numpy as np
import os
import pickle
from data_loader import load_dataset_JM 
from model import MLP 
from torch.autograd import Variable 
import math
import time

# %%
# Load trained model for path generation
mlp = MLP(42, 7) 
mlp.load_state_dict(torch.load('models/mlp_100_4000_PReLU_ae_dd_final.pkl'))
# Out:
# RuntimeErrorTraceback (most recent call last)
# <ipython-input-2-58248f246646> in <module>()
#       1 # Load trained model for path generation
#       2 mlp = MLP(42, 7)
# ----> 3 mlp.load_state_dict(torch.load('models/mlp_100_4000_PReLU_ae_dd_final.pkl'))
#
# /home/zhao/.local/lib/python2.7/site-packages/torch/serialization.pyc in load(f, map_location, pickle_module, **pickle_load_args)
#     525     with _open_file_like(f, 'rb') as opened_file:
#     526         if _is_zipfile(opened_file):
# --> 527             with _open_zipfile_reader(f) as opened_zipfile:
#     528                 return _load(opened_zipfile, map_location, pickle_module, **pickle_load_args)
#     529         return _legacy_load(opened_file, map_location, pickle_module, **pickle_load_args)
#
# /home/zhao/.local/lib/python2.7/site-packages/torch/serialization.pyc in __init__(self, name_or_buffer)
#     222 class _open_zipfile_reader(_opener):
#     223     def __init__(self, name_or_buffer):
# --> 224         super(_open_zipfile_reader, self).__init__(torch._C.PyTorchFileReader(name_or_buffer))
#     225
#     226
#
# RuntimeError: version_ <= kMaxSupportedFileFormatVersion INTERNAL ASSERT FAILED at /pytorch/caffe2/serialize/inline_container.cc:132, please report a bug to PyTorch. Attempted to read a PyTorch file with version 3, but the maximum supported version for reading is 2. Your PyTorch installation may be too old. (init at /pytorch/caffe2/serialize/inline_container.cc:132)
# frame #0: c10::Error::Error(c10::SourceLocation, std::string const&) + 0x33 (0x7f4f00926193 in /home/zhao/.local/lib/python2.7/site-packages/torch/lib/libc10.so)
# frame #1: caffe2::serialize::PyTorchStreamReader::init() + 0x1f5b (0x7f4e8a3ea9eb in /home/zhao/.local/lib/python2.7/site-packages/torch/lib/libtorch.so)
# frame #2: caffe2::serialize::PyTorchStreamReader::PyTorchStreamReader(std::string const&) + 0x64 (0x7f4e8a3ebc04 in /home/zhao/.local/lib/python2.7/site-packages/torch/lib/libtorch.so)
# frame #3: <unknown function> + 0x6c8b56 (0x7f4ed231eb56 in /home/zhao/.local/lib/python2.7/site-packages/torch/lib/libtorch_python.so)
# frame #4: <unknown function> + 0x29660b (0x7f4ed1eec60b in /home/zhao/.local/lib/python2.7/site-packages/torch/lib/libtorch_python.so)
# frame #5: <unknown function> + 0x12529e (0x55bd5221329e in /usr/bin/python)
# frame #6: <unknown function> + 0x124e4a (0x55bd52212e4a in /usr/bin/python)
# frame #7: <unknown function> + 0xe262b (0x55bd521d062b in /usr/bin/python)
# frame #8: PyEval_EvalFrameEx + 0x523e (0x55bd521e6ebe in /usr/bin/python)
# frame #9: PyEval_EvalCodeEx + 0x6da (0x55bd521df98a in /usr/bin/python)
# frame #10: <unknown function> + 0x10cb29 (0x55bd521fab29 in /usr/bin/python)
# frame #11: <unknown function> + 0x12529e (0x55bd5221329e in /usr/bin/python)
# frame #12: <unknown function> + 0x124e4a (0x55bd52212e4a in /usr/bin/python)
# frame #13: <unknown function> + 0xe262b (0x55bd521d062b in /usr/bin/python)
# frame #14: PyEval_EvalFrameEx + 0x523e (0x55bd521e6ebe in /usr/bin/python)
# frame #15: PyEval_EvalCodeEx + 0x6da (0x55bd521df98a in /usr/bin/python)
# frame #16: PyEval_EvalFrameEx + 0x541e (0x55bd521e709e in /usr/bin/python)
# frame #17: PyEval_EvalCodeEx + 0x6da (0x55bd521df98a in /usr/bin/python)
# frame #18: PyEval_EvalFrameEx + 0x40bb (0x55bd521e5d3b in /usr/bin/python)
# frame #19: PyEval_EvalCodeEx + 0x6da (0x55bd521df98a in /usr/bin/python)
# frame #20: PyEval_EvalFrameEx + 0x541e (0x55bd521e709e in /usr/bin/python)
# frame #21: PyEval_EvalCodeEx + 0x6da (0x55bd521df98a in /usr/bin/python)
# frame #22: PyEval_EvalFrameEx + 0x541e (0x55bd521e709e in /usr/bin/python)
# frame #23: PyEval_EvalCodeEx + 0x6da (0x55bd521df98a in /usr/bin/python)
# frame #24: <unknown function> + 0x10cdcc (0x55bd521fadcc in /usr/bin/python)
# frame #25: PyObject_Call + 0x3e (0x55bd521cb44e in /usr/bin/python)
# frame #26: PyEval_EvalFrameEx + 0x2c9f (0x55bd521e491f in /usr/bin/python)
# frame #27: PyEval_EvalCodeEx + 0x6da (0x55bd521df98a in /usr/bin/python)
# frame #28: PyEval_EvalFrameEx + 0x5986 (0x55bd521e7606 in /usr/bin/python)
# frame #29: PyEval_EvalCodeEx + 0x6da (0x55bd521df98a in /usr/bin/python)
# frame #30: PyEval_EvalFrameEx + 0x541e (0x55bd521e709e in /usr/bin/python)
# frame #31: PyEval_EvalCodeEx + 0x6da (0x55bd521df98a in /usr/bin/python)
# frame #32: PyEval_EvalFrameEx + 0x5986 (0x55bd521e7606 in /usr/bin/python)
# frame #33: PyEval_EvalCodeEx + 0x6da (0x55bd521df98a in /usr/bin/python)
# frame #34: PyEval_EvalFrameEx + 0x5986 (0x55bd521e7606 in /usr/bin/python)
# frame #35: PyEval_EvalCodeEx + 0x6da (0x55bd521df98a in /usr/bin/python)
# frame #36: <unknown function> + 0x10cdcc (0x55bd521fadcc in /usr/bin/python)
# frame #37: PyObject_Call + 0x3e (0x55bd521cb44e in /usr/bin/python)
# frame #38: PyEval_EvalFrameEx + 0x2c9f (0x55bd521e491f in /usr/bin/python)
# frame #39: PyEval_EvalCodeEx + 0x6da (0x55bd521df98a in /usr/bin/python)
# frame #40: <unknown function> + 0x10cdcc (0x55bd521fadcc in /usr/bin/python)
# frame #41: PyObject_Call + 0x3e (0x55bd521cb44e in /usr/bin/python)
# frame #42: PyEval_EvalFrameEx + 0x2c9f (0x55bd521e491f in /usr/bin/python)
# frame #43: PyEval_EvalCodeEx + 0x6da (0x55bd521df98a in /usr/bin/python)
# frame #44: PyEval_EvalFrameEx + 0x5986 (0x55bd521e7606 in /usr/bin/python)
# frame #45: PyEval_EvalCodeEx + 0x6da (0x55bd521df98a in /usr/bin/python)
# frame #46: PyEval_EvalFrameEx + 0x5986 (0x55bd521e7606 in /usr/bin/python)
# frame #47: PyEval_EvalCodeEx + 0x6da (0x55bd521df98a in /usr/bin/python)
# frame #48: <unknown function> + 0x10cdcc (0x55bd521fadcc in /usr/bin/python)
# frame #49: PyObject_Call + 0x3e (0x55bd521cb44e in /usr/bin/python)
# frame #50: PyEval_EvalFrameEx + 0x2c9f (0x55bd521e491f in /usr/bin/python)
# frame #51: PyEval_EvalCodeEx + 0x6da (0x55bd521df98a in /usr/bin/python)
# frame #52: PyEval_EvalFrameEx + 0x5986 (0x55bd521e7606 in /usr/bin/python)
# frame #53: PyEval_EvalCodeEx + 0x6da (0x55bd521df98a in /usr/bin/python)
# frame #54: PyEval_EvalFrameEx + 0x5986 (0x55bd521e7606 in /usr/bin/python)
# frame #55: PyEval_EvalCodeEx + 0x6da (0x55bd521df98a in /usr/bin/python)
# frame #56: PyEval_EvalFrameEx + 0x5986 (0x55bd521e7606 in /usr/bin/python)
# frame #57: PyEval_EvalCodeEx + 0x6da (0x55bd521df98a in /usr/bin/python)
# frame #58: PyEval_EvalFrameEx + 0x541e (0x55bd521e709e in /usr/bin/python)
# frame #59: PyEval_EvalCodeEx + 0x6da (0x55bd521df98a in /usr/bin/python)
# frame #60: PyEval_EvalFrameEx + 0x40bb (0x55bd521e5d3b in /usr/bin/python)
# frame #61: PyEval_EvalCodeEx + 0x6da (0x55bd521df98a in /usr/bin/python)
# frame #62: PyEval_EvalFrameEx + 0x541e (0x55bd521e709e in /usr/bin/python)
# frame #63: PyEval_EvalCodeEx + 0x6da (0x55bd521df98a in /usr/bin/python)
